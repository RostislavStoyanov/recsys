# %%
import pandas as pd
import transformers

import re
import gc
import glob
from collections import Counter

features = [
    'text_tokens',    ###############
    'hashtags',       #Tweet Features
    'tweet_id',       #
    'media',          #
    'links',          #
    'domains',        #
    'tweet_type',     #
    'language',       #
    'timestamp',      ###############
    'a_user_id',              ###########################
    'a_follower_count',       #Engaged With User Features
    'a_following_count',      #
    'a_is_verified',          #
    'a_account_creation',     ###########################
    'b_user_id',              #######################
    'b_follower_count',       #Engaging User Features
    'b_following_count',      #
    'b_is_verified',          #
    'b_account_creation',     #######################
    'b_follows_a',    #################### Engagement Features
    'reply',          #Target Reply
    'retweet',        #Target Retweet    
    'retweet_comment',#Target Retweet with comment
    'like',           #Target Like
                      ####################
]

DATA_PATH = "../data/"

# %%
df = pd.read_csv(DATA_PATH + "part-00000.tsv", header=None, names=features, sep="\x01")
df.head()
# Out:
#                                          text_tokens  \
# 0  101\t56898\t137\t10148\t96858\t18193\t11211\t1...
# 1  101\t22800\t11206\t117\t13451\t20517\t25136\t1...
# 2  101\t119\t119\t119\t45857\t85270\t10169\t77086...
# 3  101\t160\t39187\t10237\t100\t11337\t100\t13028...
# 4  101\t56898\t137\t40586\t10305\t53244\t22659\t1...
#
#                            hashtags                          tweet_id  media  \
# 0  DF367A73CB84842E4A6080F624241703  C24EA5C3E19A388895D0FA05EA9E742F  Photo
# 1                               NaN  2B41BDE7839DE3117D994FDFC9BDA6E1    NaN
# 2                               NaN  BAF10FE3481E874ED104AC0950F18784    NaN
# 3                               NaN  BCDD3DDDA04C2E7843B3734620EE0C38  Photo
# 4  86458A61FFFA24A5624A9AD8AA2F0F52  43845DCDBC2A2CA15C3B18431F48F1F8    NaN
#
#   links domains tweet_type                          language   timestamp  \
# 0   NaN     NaN    Retweet  E7F038DE3EAD397AEC9193686C911677  1612712747
# 1   NaN     NaN   TopLevel  488B32D24BD4BB44172EB981C1BCA6FA  1614002023
# 2   NaN     NaN      Quote  488B32D24BD4BB44172EB981C1BCA6FA  1612452111
# 3   NaN     NaN   TopLevel  488B32D24BD4BB44172EB981C1BCA6FA  1612980390
# 4   NaN     NaN    Retweet  488B32D24BD4BB44172EB981C1BCA6FA  1612834174
#
#                           a_user_id  ...                         b_user_id  \
# 0  419BAC1CC63FF819E98CFC5EFF52DFDA  ...  761EDF35532C3D3758DD01D33619D243
# 1  547810FE65A44B3828FFA4587D1CA0C8  ...  AE8B92F8CFE9F92C2942DEBBFE4F0FCF
# 2  E18710A5B40F9187026AA49A220857BC  ...  ED5574665DB1478CA23F13647178D9BE
# 3  0CC43EBBB61E292102397B8B08A73DDD  ...  585F08165162A5C10DE2081ECFACCFC0
# 4  29766FB1458BC9BB67EB7E61CBAB957C  ...  CAD64086EF823706DEF953E615DB6743
#
#    b_follower_count  b_following_count  b_is_verified b_account_creation  \
# 0               220                638          False         1464236635
# 1               392                487          False         1362687553
# 2              1306               5000          False         1244857625
# 3                90                 91          False         1551356429
# 4               158                411          False         1417656869
#
#    b_follows_a  reply  retweet  retweet_comment          like
# 0        False    NaN      NaN              NaN  1.612721e+09
# 1         True    NaN      NaN              NaN           NaN
# 2         True    NaN      NaN              NaN  1.612458e+09
# 3        False    NaN      NaN              NaN  1.612981e+09
# 4        False    NaN      NaN              NaN           NaN
#
# [5 rows x 24 columns]

# %%
df.dtypes
# Out:
# text_tokens            object
# hashtags               object
# tweet_id               object
# media                  object
# links                  object
# domains                object
# tweet_type             object
# language               object
# timestamp               int64
# a_user_id              object
# a_follower_count        int64
# a_following_count       int64
# a_is_verified            bool
# a_account_creation      int64
# b_user_id              object
# b_follower_count        int64
# b_following_count       int64
# b_is_verified            bool
# b_account_creation      int64
# b_follows_a              bool
# reply                 float64
# retweet               float64
# retweet_comment       float64
# like                  float64
# dtype: object

# %%
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-multilingual-cased')
tokenizer_new = transformers.XLMRobertaTokenizer.from_pretrained("cardiffnlp/twitter-xlm-roberta-base")

# %%
text_tokens_lst = df['text_tokens'].map(lambda x: tokenizer.decode([int(s) for s in x.split('\t')]))
text_tokens_lst_new = df['text_tokens'].map(lambda x: tokenizer_new.decode([int(s) for s in x.split('\t')]))

# %%
from functools import reduce
zipped = zip(text_tokens_lst, text_tokens_lst_new)
all_equal = reduce(lambda acc, x: acc and (x[0]==x[1]), zipped, True) # replace with func to stop early

print(all_equal)
# Out:
# False

# %%
example_link_comment = text_tokens_lst[3]
example_hashtag_link = text_tokens_lst[6]
example_other = text_tokens_lst[1]
print(example_link_comment)
print(example_hashtag_link)
print(example_other)
# Out:
# [CLS] Which [UNK] will [UNK] you [UNK] get [UNK] first? https : / / t. co / VMzG9d3XCC [SEP]
# [CLS] # CivilDisobedienceMovement ¶ # JusticeForMyanmar https : / / t. co / rCiRJADZOW [SEP]
# [CLS] Oh well, next stop Rotterdam @ janniksin, hope to see you play there. : ) [SEP]

# %%
def clean_and_count_urls(tweet, counter=None):
    str_list = []
    prev_idx = 0
    link_cnt = 0
    for url in re.finditer("(https : \/(\s(\/\s)?\w+(\.)?)+)", tweet):
        str_list.append(tweet[prev_idx:url.start()])
        str_list.append(tweet[url.start():url.end()].replace(" ", ""))
        prev_idx = url.end() + 1
        link_cnt += 1
        
    if counter is not None:
        counter[link_cnt] += 1
    if(len(str_list)==0):
        return tweet
    return "".join(str_list)



def remove_urls(tweet, counter = None):
    str_list = []
    prev_idx = 0
    link_cnt = 0
    for url in re.finditer("(https : \/(\s(\/\s)?\w+(\.)?)+)", tweet):
        str_list.append(tweet[prev_idx:url.start()])
        #str_list.append("")
        prev_idx = url.end() + 1
        link_cnt += 1
        
    if counter is not None:
        counter[link_cnt] += 1
    if(len(str_list)==0):
        return tweet
    return "".join(str_list)

def replace_urls(tweet, counter = None):
    str_list = []
    prev_idx = 0
    link_cnt = 0
    for url in re.finditer("(https : \/(\s(\/\s)?\w+(\.)?)+)", tweet):
        str_list.append(tweet[prev_idx:url.start()])
        str_list.append("[LINK]")
        prev_idx = url.end() + 1
        link_cnt += 1
        
    if counter is not None:
        counter[link_cnt] += 1
    if(len(str_list)==0):
        return tweet
    return "".join(str_list)

# %%
print(clean_and_count_urls(example_link_comment))
print(clean_and_count_urls(example_hashtag_link))

print(remove_urls(example_link_comment))
print(remove_urls(example_hashtag_link))

print(replace_urls(example_link_comment))
print(replace_urls(example_hashtag_link))
# Out:
# [CLS] Which [UNK] will [UNK] you [UNK] get [UNK] first? https://t.co/VMzG9d3XCC
# [CLS] # CivilDisobedienceMovement ¶ # JusticeForMyanmar https://t.co/rCiRJADZOW
# [CLS] Which [UNK] will [UNK] you [UNK] get [UNK] first?
# [CLS] # CivilDisobedienceMovement ¶ # JusticeForMyanmar
# [CLS] Which [UNK] will [UNK] you [UNK] get [UNK] first? [LINK]
# [CLS] # CivilDisobedienceMovement ¶ # JusticeForMyanmar [LINK]

# %%
for i in range(0,25):
    print(clean_and_count_urls(text_tokens_lst[i]))
# Out:
# [CLS] RT @ sakuramt6 : [UNK] # みかじ 絵 https://t.co/UdWRUepkMQ
# [CLS] Oh well, next stop Rotterdam @ janniksin, hope to see you play there. : ) [SEP]
# [CLS]... replacing Ares with Athena [UNK] [SEP]
# [CLS] Which [UNK] will [UNK] you [UNK] get [UNK] first? https://t.co/VMzG9d3XCC
# [CLS] RT @ BrainzNBoobiez : Whew... this just gave me chills... # TheWaitIsOver [SEP]
# [CLS] Diktaturmegafonen [SEP]
# [CLS] # CivilDisobedienceMovement ¶ # JusticeForMyanmar https://t.co/rCiRJADZOW
# [CLS] RT @ mystarplay : [UNK] # 스타플레이 # 3월 # 생일투표 1 / [UNK] ¶ [UNK] # 3월생일 # [UNK] ¶ ¶ [UNK] ¶ [UNK] 초대형 생일전광판 ¶ [UNK] 파르나스몰 미디어패널 ( 39개 ) ¶ [UNK] ¶ ¶ [UNK] ¶ [UNK] ¶ ¶ # starplay 앱에서 [UNK] [SEP]
# [CLS] RT @ FaseehMangi : Pakistan fiscal deficit rises to 2. 5 % in six months vs 2. 3 %, some key numbers : ¶ Tax revenue [UNK] - 0. 4 % ¶ Government expenditures [UNK] [SEP]
# [CLS] The Right will push conspiracy theories and fascistic fearmongering until it stops being profitable or costs them power. ¶ ¶ They [UNK] re not going to just stop because of conscience or the turning of a page. We [UNK] re watching a new generation of dangerous grifters get theirs. [SEP]
# [CLS] When it's inside the ear but the pussy is feeling it [UNK] https://t.co/ffjLqZwo61
# [CLS] friendly reminder that oh sehun is korea [UNK] s levi ackerman https://t.co/nJLn5MsFvf
# [CLS] Nothing I hate more than creepy white guys at the bar who have zero boundaries for anything or anyone. [SEP]
# [CLS] ¿ Será buena guardar los lives de Monsta X? [UNK] ¶ Estaba pensando en grabar algunos lives ( no se cuales aún ) con subs en español y subirlos ya sea a drive o a YouTube. ¶ Tengo algo de tiempo libre para hacerlo. ¶ @ OfficialMonstaX @ official _ _ wonho [SEP]
# [CLS] ばいーといってーくる [SEP]
# [CLS] RT @ Riox _ 9 : 超 新 星 らしいです [SEP]
# [CLS] الصاحب الي يقلك مالي نفس اطلع اعرف انه مطفر ولازم تستحي على وجهك وتفهم وتعزمو [SEP]
# [CLS] RT @ taho _ 02 : # まほやく _ FA [UNK] https://t.co/o01K9jUUH9
# [CLS] RT @ SLAMonline : The ball hasn [UNK] t stopped bouncing. Live on. https://t.co/6HbXvakKkv
# [CLS] RT @ atwistedfool : first time https://t.co/OnTzNtXLPA
# [CLS] que dieu me pardonne d [UNK] avoir [UNK] https://t.co/kjByDi2MZS
# [CLS] If Chicken Manchurian is India's revenge on Chinese cuisine, Pakistani politicians'' LONG MARCH'is Pakistan's revenge on Chinese political history... every few months Pk politicians carry out a long march, some of which are only a few Kms long, and all of them in luxury SUVs [SEP]
# [CLS] RT @ halfmillion _ sa : فطور الشيوخ بنكهة # طعم _ الصباح [UNK] https://t.co/2BMMBfKvyT
# [CLS] Damn [UNK] [SEP]
# [CLS] ラクガキ 王 国 楽 しみだなぁ 。 [SEP]

# %%
cnt = Counter()

links_fixed = text_tokens_lst.map(lambda x: clean_and_count_urls(x, cnt))

# %%
print(cnt)
# Out:
# Counter({0: 1771144, 1: 1474707, 2: 49736, 3: 3857, 4: 842, 5: 291, 6: 115, 7: 50, 8: 14, 9: 9, 10: 4, 11: 1})

# %%
def remove_urls_and_count(tweet):
    str_list = []
    prev_idx = 0
    link_cnt = 0
    for url in re.finditer("(https : \/(\s(\/\s)?\w+(\.)?)+)", tweet):
        str_list.append(tweet[prev_idx:url.start()])
        str_list.append(tweet[url.start():url.end()].replace(" ", ""))
        prev_idx = url.end() + 1
        link_cnt += 1
        
    if(len(str_list)==0):
        return (tweet, 0)
    return ("".join(str_list), link_cnt)

#print(remove_urls_and_count(example_link_comment))

# %%
all_files = glob.glob(DATA_PATH+"*.tsv")
all_files.sort()

train_files = all_files[:10]
valid_files = all_files[-10:-5]
test_files = all_files[-5:]

# %%
valid_df = pd.concat((pd.read_csv(valid_file, header=None, names=features, sep="\x01") for valid_file in valid_files))
valid_df.to_csv(DATA_PATH+"valid_small.csv")

# %%
test_df = pd.concat((pd.read_csv(test_file, header=None, names=features, sep="\x01") for test_file in test_files))
test_df.to_csv(DATA_PATH+"test_small.csv")

# %%
del valid_df
del test_df
gc.collect()
# Out:
# 137

# %%
train_df = pd.concat((pd.read_csv(train_file, header=None, names=features, sep="\x01") for train_file in train_files))

# %%
text_tokens_lst = train_df['text_tokens'].map(lambda x: tokenizer.decode([int(s) for s in x.split('\t')]))

# %%
cleaned_urls = text_tokens_lst.map(lambda x: remove_urls_and_count(x))
del text_tokens_lst

# %%
a, b = zip(*cleaned_urls[:5])
urls, counts = zip(*cleaned_urls)

# %%
del cleaned_urls

# %%
train_df['url_cnt'] = counts
train_df.to_csv(DATA_PATH+"train_small.csv")

# %%
def convert_tweet_back_to_ids(tweet):
    ids_lst = tokenizer.convert_tokens_to_ids(tokenizer.tokenize(urls[3]))
    ids_lst = [str(id) for id in ids_lst]
    
    return '\t'.join(ids_lst)
    
train_df['text_tokens'].apply(convert_tweet_back_to_ids)
train_df.head()
# Out:
#                                          text_tokens  \
# 0  101\t56898\t137\t10148\t96858\t18193\t11211\t1...
# 1  101\t22800\t11206\t117\t13451\t20517\t25136\t1...
# 2  101\t119\t119\t119\t45857\t85270\t10169\t77086...
# 3  101\t160\t39187\t10237\t100\t11337\t100\t13028...
# 4  101\t56898\t137\t40586\t10305\t53244\t22659\t1...
#
#                            hashtags                          tweet_id  media  \
# 0  DF367A73CB84842E4A6080F624241703  C24EA5C3E19A388895D0FA05EA9E742F  Photo
# 1                               NaN  2B41BDE7839DE3117D994FDFC9BDA6E1    NaN
# 2                               NaN  BAF10FE3481E874ED104AC0950F18784    NaN
# 3                               NaN  BCDD3DDDA04C2E7843B3734620EE0C38  Photo
# 4  86458A61FFFA24A5624A9AD8AA2F0F52  43845DCDBC2A2CA15C3B18431F48F1F8    NaN
#
#   links domains tweet_type                          language   timestamp  \
# 0   NaN     NaN    Retweet  E7F038DE3EAD397AEC9193686C911677  1612712747
# 1   NaN     NaN   TopLevel  488B32D24BD4BB44172EB981C1BCA6FA  1614002023
# 2   NaN     NaN      Quote  488B32D24BD4BB44172EB981C1BCA6FA  1612452111
# 3   NaN     NaN   TopLevel  488B32D24BD4BB44172EB981C1BCA6FA  1612980390
# 4   NaN     NaN    Retweet  488B32D24BD4BB44172EB981C1BCA6FA  1612834174
#
#                           a_user_id  ...  b_follower_count  b_following_count  \
# 0  419BAC1CC63FF819E98CFC5EFF52DFDA  ...               220                638
# 1  547810FE65A44B3828FFA4587D1CA0C8  ...               392                487
# 2  E18710A5B40F9187026AA49A220857BC  ...              1306               5000
# 3  0CC43EBBB61E292102397B8B08A73DDD  ...                90                 91
# 4  29766FB1458BC9BB67EB7E61CBAB957C  ...               158                411
#
#    b_is_verified  b_account_creation b_follows_a  reply  retweet  \
# 0          False          1464236635       False    NaN      NaN
# 1          False          1362687553        True    NaN      NaN
# 2          False          1244857625        True    NaN      NaN
# 3          False          1551356429       False    NaN      NaN
# 4          False          1417656869       False    NaN      NaN
#
#    retweet_comment          like  url_cnt
# 0              NaN  1.612721e+09        1
# 1              NaN           NaN        0
# 2              NaN  1.612458e+09        0
# 3              NaN  1.612981e+09        1
# 4              NaN           NaN        0
#
# [5 rows x 25 columns]

# %%
train_df.to_csv(DATA_PATH+"train_small_no_urls.csv")
